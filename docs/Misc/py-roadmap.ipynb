# %% [markdown]
# # Python Beginner Roadmap
#
# ## Stage 0: Setup & Mindset (Day 0)
#
# ### What to Do
#
# * Install **Python 3.10+**
# * Install **Conda / Miniconda**
# * Install **JupyterLab**
# * Learn how to:
#
#   * Run Python in terminal
#   * Run code in Jupyter
#
# ### Goal
#
# ✔ You can run Python code successfully
#
# ---
#
# ## Stage 1: Python Basics (Week 1)
#
# ### Core Syntax
#
# Learn these first:
#
# * Variables
# * Basic data types:
#
#   * `int`, `float`
#   * `str`
#   * `bool`
# * Comments
# * `print()`
#
# Example:
#
# ```python
# age = 18
# name = "Alice"
# print(age, name)
# ```
#
# ---
#
# ### Operators
#
# * Arithmetic: `+ - * / // % **`
# * Comparison: `== != > < >= <=`
# * Logical: `and or not`
#
# ---
#
# ### Input & Output
#
# ```python
# name = input("Enter your name: ")
# print("Hello", name)
# ```
#
# ---
#
# ### Goal
#
# ✔ Write simple scripts
#
# ✔ Understand what each line does
#
# ---
#
# ## Stage 2: Control Flow (Week 2)
#
# ### Conditional Statements
#
# ```python
# if score >= 60:
#     print("Pass")
# else:
#     print("Fail")
# ```
#
# ---
#
# ### Loops
#
# * `for`
# * `while`
#
# ```python
# for i in range(5):
#     print(i)
# ```
#
# ---
#
# ### Loop Control
#
# * `break`
# * `continue`
#
# ---
#
# ### Goal
#
# ✔ Make decisions in code
#
# ✔ Automate repetitive tasks
#
# ---
#
# ## Stage 3: Data Structures (Week 3)
#
# ### Must-Know Structures
#
# * `list`
# * `tuple`
# * `dict`
# * `set`
#
# ```python
# scores = [90, 85, 88]
# student = {"name": "Tom", "age": 20}
# ```
#
# ---
#
# ### Common Operations
#
# * Indexing & slicing
# * Adding / removing elements
# * Iteration
#
# ---
#
# ### Goal
#
# ✔ Store and manage collections of data
#
# ✔ Choose the right structure
#
# ---
#
# ## Stage 4: Functions & Modules (Week 4)
#
# ### Functions
#
# ```python
# def add(a, b):
#     return a + b
# ```
#
# Learn:
#
# * Parameters
# * Return values
# * Default arguments
#
# ---
#
# ### Modules
#
# * `import`
# * `from ... import ...`
#
# ```python
# import math
# print(math.sqrt(16))
# ```
#
# ---
#
# ### Goal
#
# ✔ Write reusable code
#
# ✔ Understand code organization
#
# ---
#
# ## Stage 5: Error Handling & Debugging (Week 5)
#
# ### Exceptions
#
# ```python
# try:
#     x = int("abc")
# except ValueError:
#     print("Invalid number")
# ```
#
# ---
#
# ### Debugging Skills
#
# * Read error messages
# * Use `print()` wisely
# * Understand stack traces
#
# ---
#
# ### Goal
#
# ✔ Fix errors independently
# ✔ Not fear exceptions
#
# ---
#
# ## Stage 6: File & OS Operations (Week 6)
#
# ### File I/O
#
# ```python
# with open("data.txt", "r") as f:
#     content = f.read()
# ```
#
# ---
#
# ### OS Interaction
#
# * `os`
# * `pathlib`
#
# ```python
# from pathlib import Path
# Path("test.txt").exists()
# ```
#
# ---
#
# ### Goal
#
# ✔ Read/write files
# ✔ Automate local tasks
#
# ---
#
# ## Stage 7: Virtual Environments & Packaging (Week 7)
#
# ### Environment Tools
#
# * `conda`
# * `venv`
# * `pip`
#
# ---
#
# ### Skills
#
# * Create environments
# * Install dependencies
# * Freeze requirements
#
# ---
#
# ### Goal
#
# ✔ Avoid dependency conflicts
# ✔ Reproducible projects
#
# ---
#
# ## Stage 8: Choose Your Direction (Week 8+)
#
# At this point, **branch out**.
#
# ---
#
# ### 🔹 Path A: Data Analysis / AI
#
# Learn:
#
# * `numpy`
# * `pandas`
# * `matplotlib`
# * `scikit-learn`
#
# Projects:
#
# * Data cleaning
# * Visualization
# * Simple ML models
#
# ---
#
# ### 🔹 Path B: Backend / Web
#
# Learn:
#
# * HTTP basics
# * `flask` or `django`
# * REST APIs
# * Databases (SQLite / MySQL)
#
# Projects:
#
# * Blog system
# * REST API service
#
# ---
#
# ### 🔹 Path C: Automation / Tools
#
# Learn:
#
# * `requests`
# * `beautifulsoup`
# * `argparse`
# * `click`
#
# Projects:
#
# * Web scraper
# * CLI tools
# * Batch automation
#
# ---
#
# ### 🔹 Path D: Systems / Performance
#
# Learn:
#
# * C extensions
# * `ctypes`
# * Multiprocessing
# * Async programming
#
# ---
#
# ## Stage 9: Best Practices (Always Learn)
#
# ### Coding Style
#
# * PEP 8
# * Meaningful variable names
#
# ### Testing
#
# * `unittest`
# * `pytest`
#
# ### Version Control
#
# * Git basics
#
# ---
#
# ## Stage 10: Build Real Projects (Most Important)
#
# Examples:
#
# * To-do app
# * Password manager
# * Log analyzer
# * File organizer
# * Mini crawler
#
# ✔ Projects = real learning
#
# ---
#
# ## Daily Learning Plan (Recommended)
#
# | Time   | Activity                |
# | ------ | ----------------------- |
# | 30 min | Learn new concepts      |
# | 30 min | Code examples           |
# | 30 min | Practice / mini project |
#
# ---
#
# ## Common Beginner Traps
#
# ❌ Watching tutorials without coding
#
# ❌ Learning everything at once
#
# ❌ Avoiding errors
#
# ❌ Copy–paste without understanding
#
# ---
#
# ## Final Advice
#
# > **Python is learned by writing Python.**
#
# Small steps → consistency → real projects.
