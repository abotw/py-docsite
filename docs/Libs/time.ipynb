# %% [markdown]
# # Time

# %%
import time

# %%
time.time()
# Out:
# 1765396046.6901262

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2025, tm_mon=12, tm_mday=11, tm_hour=3, tm_min=47, tm_sec=26, tm_wday=3, tm_yday=345, tm_isdst=0)

# %%
time.asctime()
# Out:
# 'Thu Dec 11 03:47:26 2025'

# %%
time.mktime(time.localtime())
# Out:
# 1765396046.0
